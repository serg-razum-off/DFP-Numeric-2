# %% [markdown]
# # Imports

# %%
import os, sys
import pandas as pd

sys.path.insert(0, "./classes/")
import cls_data

# %%
# reloading functions without runtime.restart
import importlib
importlib.reload(cls_data)
# Out:
# <module 'cls_data' from './classes/cls_data.py'>

# %% [markdown]
# # Previewing data

# %%
dir_path = "../data/"

# %%
# this is for Linux
# !ls -lagh {dir_path}

# this is for Windows
# ! dir "../data/"
# Out:
# total 1.3M
# drwxrwxrwx 1 1000  512 May 28 10:46 .
# drwxrwxrwx 1 1000  512 May 28 10:19 ..
# drwxrwxrwx 1 1000  512 May 28 09:25 .ipynb_checkpoints
# -rwxrwxrwx 1 1000 125K May 28 10:45 BCHAIN-AVBLS.csv
# -rwxrwxrwx 1 1000 113K May 28 10:45 BCHAIN-CPTRA.csv
# -rwxrwxrwx 1 1000 122K May 28 10:45 BCHAIN-HRATE.csv
# -rwxrwxrwx 1 1000 105K May 28 10:45 BCHAIN-MIREV.csv
# -rwxrwxrwx 1 1000  79K May 28 10:45 BCHAIN-MWNTD.csv
# -rwxrwxrwx 1 1000  87K May 28 10:45 BCHAIN-MWNUS.csv
# -rwxrwxrwx 1 1000  95K May 28 10:45 BCHAIN-MWTRV.csv
# -rwxrwxrwx 1 1000  96K May 28 10:45 BCHAIN-TOTBC.csv
# -rwxrwxrwx 1 1000  98K May 28 10:45 BCHAIN-TRFEE.csv
# -rwxrwxrwx 1 1000 104K May 28 10:45 BCHAIN-TRVOU.csv
# -rwxrwxrwx 1 1000 259K May 28 10:19 BTC-RatesHistData.csv
# -rwxrwxrwx 1 1000 8.6K May 28 10:46 csv_loader.ipynb
# -rwxrwxrwx 1 1000 2.2K May 27 11:27 files_properties.csv

# %% [markdown]
# ## Features Meaning

# %% [markdown]
# ## Init DataManager, previewing BTC data

# %%
pd.read_csv(os.path.join(dir_path, "BTC-RatesHistData.csv"))[:5]
# Out:
#            Date     Price      Open      High       Low     Vol. Change %
# 0  May 28, 2021  35,854.7  38,543.2  38,844.1  35,446.8  146.84K   -6.67%
# 1  May 27, 2021  38,417.3  39,249.0  40,322.2  37,190.8  122.93K   -2.12%
# 2  May 26, 2021  39,249.2  38,375.7  40,750.0  37,847.0  153.80K    2.27%
# 3  May 25, 2021  38,378.3  38,753.6  39,740.8  36,540.7  163.01K   -0.96%
# 4  May 24, 2021  38,750.6  34,720.3  39,851.7  34,474.6  244.88K   11.74%

# %%
btc_exch_rates_filename = "BTC-RatesHistData.csv"
data_manager = cls_data.DataManager(dir_path=dir_path, btc_exch_rates_filename=btc_exch_rates_filename)

# %%
data_manager.data_btc[:5]
# Out:
#               Price     Open     High      Low       Vol  Growth     AVBLS  \
# Date
# 2021-05-26  39249.2  38375.7  40750.0  37847.0  153800.0  0.0227  1.300155
# 2021-05-25  38378.3  38753.6  39740.8  36540.7  163010.0 -0.0096  1.359463
# 2021-05-24  38750.6  34720.3  39851.7  34474.6  244880.0  0.1174  1.345943
# 2021-05-23  34679.7  37446.8  38248.7  31192.4  325730.0 -0.0739  1.379972
# 2021-05-22  37448.3  37291.0  38776.0  35314.9  185830.0  0.0040  1.289550
#
#                  CPTRA         HRATE         MIREV    MWNTD       MWNUS  \
# Date
# 2021-05-26  142.908721  1.518983e+08  3.297662e+07  72182.0  73365685.0
# 2021-05-25  139.434045  1.531433e+08  3.257793e+07  67560.0  73329130.0
# 2021-05-24  139.161241  1.568785e+08  3.266880e+07  65573.0  73277908.0
# 2021-05-23  148.951003  1.481631e+08  2.894416e+07  44844.0  73224985.0
# 2021-05-22  138.856769  1.444278e+08  3.107614e+07  52778.0  73178063.0
#
#                    MWTRV        TOTBC  Btc_Mined       TRFEE         TRVOU
# Date
# 2021-05-26  24410.501195  18719118.75     875.00   77.846658  7.191548e+08
# 2021-05-25  21150.838784  18718462.50     656.25   85.818131  1.032789e+09
# 2021-05-24  16982.264394  18717587.50     875.00   96.801943  1.106858e+09
# 2021-05-23  14841.587710  18716931.25     656.25   81.406769  6.660316e+08
# 2021-05-22  18070.969990  18716087.50     843.75  102.381368  1.438210e+09

# %% [markdown]
# ## Previewing Features

# %%
data_manager.data_btc.columns
# Out:
# Index(['Price', 'Open', 'High', 'Low', 'Vol', 'Growth', 'AVBLS', 'CPTRA',
#        'HRATE', 'MIREV', 'MWNTD', 'MWNUS', 'MWTRV', 'TOTBC', 'Btc_Mined',
#        'TRFEE', 'TRVOU'],
#       dtype='object')

# %%
data_manager.data_files_prop
# Out:
#                  FileName                                          Meaning  \
# 0   BTC-RatesHistData.csv                Bitcoin Exchange Rates Statistics
# 1        BCHAIN-AVBLS.csv                       Bitcoin Average Block Size
# 2        BCHAIN-HRATE.csv                                Bitcoin Hash Rate
# 3        BCHAIN-MIREV.csv                           Bitcoin Miners Revenue
# 4        BCHAIN-MWNTD.csv  Bitcoin My Wallet Number of Transaction Per Day
# 5        BCHAIN-TOTBC.csv                    Total Bitcoins in Circulation
# 6        BCHAIN-CPTRA.csv                     Bitcoin Cost Per Transaction
# 7        BCHAIN-TRVOU.csv                Bitcoin USD Exchange Trade Volume
# 8        BCHAIN-MWTRV.csv             Bitcoin My Wallet Transaction Volume
# 9        BCHAIN-MWNUS.csv                Bitcoin My Wallet Number of Users
# 10       BCHAIN-TRFEE.csv                   Bitcoin Total Transaction Fees
#
#                                                   url  \
# 0   https://www.investing.com/crypto/bitcoin/histo...
# 1   https://www.quandl.com/data/BCHAIN/AVBLS-Bitco...
# 2   https://www.quandl.com/data/BCHAIN/HRATE-Bitco...
# 3   https://www.quandl.com/data/BCHAIN/MIREV-Bitco...
# 4   https://www.quandl.com/data/BCHAIN/MWNTD-Bitco...
# 5   https://www.quandl.com/data/BCHAIN/TOTBC-Total...
# 6   https://www.quandl.com/data/BCHAIN/CPTRA-Bitco...
# 7   https://www.quandl.com/data/BCHAIN/TRVOU-Bitco...
# 8   https://www.quandl.com/data/BCHAIN/MWTRV-Bitco...
# 9   https://www.quandl.com/data/BCHAIN/MWNUS-Bitco...
# 10  https://www.quandl.com/data/BCHAIN/TRFEE-Bitco...
#
#                                               csv_url
# 0                                                 NaN
# 1   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 2   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 3   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 4   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 5   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 6   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 7   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 8   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 9   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 10  https://www.quandl.com/api/v3/datasets/BCHAIN/...

# %% [markdown]
# ## Price Preview

# %%
data_manager._plt_plot_timeseries("Price", titles=dict(title="Price of Bitcoin dynamics over time"), fig_size=(16,5))

# %% [markdown]
# ## All Major Features Preview

# %%
data_manager.preview_features_ts(features_skip=['Open', 'High', 'Low'], fig_size=(25,50))
