# %% [markdown]
# # Imports

# %%
import os, sys
import pandas as pd

sys.path.insert(0, "./classes/")
import cls_data

# %%
# reloading functions without runtime.restart
import importlib
importlib.reload(cls_data)
# Out:
# <module 'cls_data' from './classes/cls_data.py'>

# %% [markdown]
# # Previewing data

# %%
dir_path = "../data/"

# %%
# this is for Linux
# !ls -lagh {dir_path}

# this is for Windows
# ! dir "../data/"
# Out:
# total 1.3M
# drwxrwxrwx 1 1000  512 May 27 11:26 .
# drwxrwxrwx 1 1000  512 May 27 09:07 ..
# -rwxrwxrwx 1 1000 120K May 26 07:16 BCHAIN-AVBLS.csv
# -rwxrwxrwx 1 1000 109K May 26 07:16 BCHAIN-CPTRA.csv
# -rwxrwxrwx 1 1000 119K May 26 07:16 BCHAIN-HRATE.csv
# -rwxrwxrwx 1 1000 103K May 26 07:16 BCHAIN-MIREV.csv
# -rwxrwxrwx 1 1000  79K May 26 07:16 BCHAIN-MWNTD.csv
# -rwxrwxrwx 1 1000  87K May 27 08:07 BCHAIN-MWNUS.csv
# -rwxrwxrwx 1 1000  93K May 26 07:16 BCHAIN-MWTRV.csv
# -rwxrwxrwx 1 1000  96K May 26 07:16 BCHAIN-TOTBC.csv
# -rwxrwxrwx 1 1000  97K May 27 10:57 BCHAIN-TRFEE.csv
# -rwxrwxrwx 1 1000 101K May 26 07:16 BCHAIN-TRVOU.csv
# -rwxrwxrwx 1 1000 262K May 26 07:16 BTC-RatesHistData.csv
# -rwxrwxrwx 1 1000 2.2K May 27 11:26 files_properties.csv

# %% [markdown]
# ## Features Meaning

# %% [markdown]
# ## Init DataManager, previewing BTC data

# %%
pd.read_csv(os.path.join(dir_path, "BTC-RatesHistData.csv"))[:5]
# Out:
#            Date     Price      Open      High       Low     Vol. Change %
# 0  May 21, 2021  41,156.6  40,611.2  42,108.3  39,251.8  204.98K    1.08%
# 1  May 20, 2021  40,717.2  36,706.8  42,425.9  35,010.4  269.75K   10.88%
# 2  May 19, 2021  36,720.5  42,898.3  43,516.6  30,261.7  607.10K  -14.40%
# 3  May 18, 2021  42,897.3  43,538.5  45,770.9  42,293.9  154.96K   -1.48%
# 4  May 17, 2021  43,541.3  46,424.2  46,545.4  42,201.5  274.76K   -6.21%

# %%
btc_exch_rates_filename = "BTC-RatesHistData.csv"
data_manager = cls_data.DataManager(dir_path=dir_path, btc_exch_rates_filename=btc_exch_rates_filename)
# Out:
# !!! add to files_properties descr of files with these columns:
# ['MWNUS']

# %%
data_manager.data_btc[:5]
# Out:
#               Price     Open     High      Low       Vol  Growth     AVBLS  \
# Date
# 2021-05-20  40717.2  36706.8  42425.9  35010.4  269750.0  0.1088  1.304127
# 2021-05-19  36720.5  42898.3  43516.6  30261.7  607100.0 -0.1440  1.322286
# 2021-05-18  42897.3  43538.5  45770.9  42293.9  154960.0 -0.0148  1.332187
# 2021-05-17  43541.3  46424.2  46545.4  42201.5  274760.0 -0.0621  1.334122
# 2021-05-16  46426.4  46729.3  49764.3  43920.8  180070.0 -0.0060  1.371701
#
#                  CPTRA         HRATE         MIREV    MWNTD       MWNUS  \
# Date
# 2021-05-20  145.306445  1.394476e+08  3.313554e+07  61117.0  73118150.0
# 2021-05-19  136.744405  1.556335e+08  3.655889e+07  62153.0  73079866.0
# 2021-05-18  138.579967  1.245068e+08  3.062867e+07  61039.0  73024411.0
# 2021-05-17  146.966607  1.506532e+08  3.687539e+07  66717.0  72994856.0
# 2021-05-16  190.074887  1.643489e+08  4.170908e+07  55503.0  72951528.0
#
#                    MWTRV        TOTBC  Btc_Mined       TRFEE         TRVOU
# Date
# 2021-05-20  27391.464033  18714781.25     656.25  132.476354  3.192479e+09
# 2021-05-19  60807.174470  18713906.25     875.00  122.724683  7.764210e+08
# 2021-05-18  21695.324703  18713237.50     668.75   67.164874  1.365357e+09
# 2021-05-17  32399.128251  18712581.25     656.25   76.189070  7.955406e+08
# 2021-05-16  17956.282312  18711762.50     818.75   52.094144  5.366584e+08

# %% [markdown]
# ## Previewing Features

# %%
data_manager.data_btc.columns
# Out:
# Index(['Price', 'Open', 'High', 'Low', 'Vol', 'Growth', 'AVBLS', 'CPTRA',
#        'HRATE', 'MIREV', 'MWNTD', 'MWNUS', 'MWTRV', 'TOTBC', 'Btc_Mined',
#        'TRFEE', 'TRVOU'],
#       dtype='object')

# %%
data_manager.data_files_prop
# Out:
#                  FileName                                          Meaning  \
# 0   BTC-RatesHistData.csv                Bitcoin Exchange Rates Statistics
# 1        BCHAIN-AVBLS.csv                       Bitcoin Average Block Size
# 2        BCHAIN-HRATE.csv                                Bitcoin Hash Rate
# 3        BCHAIN-MIREV.csv                           Bitcoin Miners Revenue
# 4        BCHAIN-MWNTD.csv  Bitcoin My Wallet Number of Transaction Per Day
# 5        BCHAIN-TOTBC.csv                    Total Bitcoins in Circulation
# 6        BCHAIN-CPTRA.csv                     Bitcoin Cost Per Transaction
# 7        BCHAIN-TRVOU.csv                Bitcoin USD Exchange Trade Volume
# 8        BCHAIN-MWTRV.csv             Bitcoin My Wallet Transaction Volume
# 9                     NaN                Bitcoin My Wallet Number of Users
# 10       BCHAIN-TRFEE.csv                   Bitcoin Total Transaction Fees
#
#                                                   url  \
# 0   https://www.investing.com/crypto/bitcoin/histo...
# 1   https://www.quandl.com/data/BCHAIN/AVBLS-Bitco...
# 2   https://www.quandl.com/data/BCHAIN/HRATE-Bitco...
# 3   https://www.quandl.com/data/BCHAIN/MIREV-Bitco...
# 4   https://www.quandl.com/data/BCHAIN/MWNTD-Bitco...
# 5   https://www.quandl.com/data/BCHAIN/TOTBC-Total...
# 6   https://www.quandl.com/data/BCHAIN/CPTRA-Bitco...
# 7   https://www.quandl.com/data/BCHAIN/TRVOU-Bitco...
# 8   https://www.quandl.com/data/BCHAIN/MWTRV-Bitco...
# 9   https://www.quandl.com/data/BCHAIN/MWNUS-Bitco...
# 10  https://www.quandl.com/data/BCHAIN/TRFEE-Bitco...
#
#                                               csv_url
# 0                                                 NaN
# 1   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 2   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 3   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 4   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 5   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 6   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 7   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 8   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 9   https://www.quandl.com/api/v3/datasets/BCHAIN/...
# 10  https://www.quandl.com/api/v3/datasets/BCHAIN/...

# %%
pd.read_csv(os.path.join(dir_path, "BTC-RatesHistData.csv"))
# Out:
#               Date     Price      Open      High       Low     Vol. Change %
# 0     May 21, 2021  41,156.6  40,611.2  42,108.3  39,251.8  204.98K    1.08%
# 1     May 20, 2021  40,717.2  36,706.8  42,425.9  35,010.4  269.75K   10.88%
# 2     May 19, 2021  36,720.5  42,898.3  43,516.6  30,261.7  607.10K  -14.40%
# 3     May 18, 2021  42,897.3  43,538.5  45,770.9  42,293.9  154.96K   -1.48%
# 4     May 17, 2021  43,541.3  46,424.2  46,545.4  42,201.5  274.76K   -6.21%
# ...            ...       ...       ...       ...       ...      ...      ...
# 3956  Jul 22, 2010       0.1       0.1       0.1       0.1    2.16K    0.00%
# 3957  Jul 21, 2010       0.1       0.1       0.1       0.1    0.58K    0.00%
# 3958  Jul 20, 2010       0.1       0.1       0.1       0.1    0.26K    0.00%
# 3959  Jul 19, 2010       0.1       0.1       0.1       0.1    0.57K    0.00%
# 3960  Jul 18, 2010       0.1       0.0       0.1       0.1    0.08K    0.00%
#
# [3961 rows x 7 columns]

# %%
data_manager.preview_features(features_skip=['Open', 'High', 'Low'], fig_size=(25,30))
